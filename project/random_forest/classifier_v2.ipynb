# %% [markdown]
# ## Random Forest
#
# Классификация типа совпадения RFQ–Supplier (match, weak_match, related) на основе текстовых признаков (TF-IDF) и RandomForestClassifier.

# %% [markdown]
# ---
# ## 1. Импорты и настройки

# %%
import pandas as pd
import numpy as np
from pathlib import Path

from sklearn.model_selection import GroupShuffleSplit
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# ## 2. Загрузка данных

# %%
data_path = Path("../dataset/dataset_1k.csv")
df = pd.read_csv(data_path)

print("Форма датасета:", df.shape)
print("Колонки:", df.columns)
# Out:
# Форма датасета: (1000, 15)
# Колонки: Index(['rfq_id', 'rfq_title', 'rfq_description', 'delivery_location',
#        'quantity', 'rfq_supplier_types', 'supplier_name', 'supplier_country',
#        'distribution_area', 'supplier_description', 'supplier_types',
#        'products', 'product_categories', 'keywords', 'match_type'],
#       dtype='object')

# %% [markdown]
# ---
# ## 3. Предобработка
#
# Очистка полей в формате PostgreSQL-массивов (фигурные скобки), подсчёт пропусков, заполнение пропусков в текстовых полях, формирование признаков `rfq_text` и `supplier_text`.

# %%
def clean_array_field(s: str) -> str:
    if pd.isna(s):
        return ""
   
    s = str(s).strip()
    if s.startswith("{") and s.endswith("}"):
        s = s[1:-1]

    return s.replace(",", ", ")

# Колонки в формате массива
array_columns = [
    "rfq_supplier_types", "supplier_types", "products", "product_categories", "keywords"
]
for col in array_columns:
    if col in df.columns:
        df[col] = df[col].apply(clean_array_field)

# %%
# Количество пропусков по колонкам до заполнения
nan_counts = df.isna().sum()
print("Пропуски по колонкам (до заполнения):")
for col in df.columns:
    if nan_counts[col] > 0:
        print(f"  {col}: {nan_counts[col]}")
# Out:
# Пропуски по колонкам (до заполнения):
#   supplier_country: 1
#   distribution_area: 271
#   supplier_description: 345

# %%
# Заполняем пропуски в текстовых полях пустой строкой
text_columns = [
    "rfq_title", "rfq_description", "delivery_location", "quantity",
    "rfq_supplier_types", "supplier_name", "supplier_country", "distribution_area",
    "supplier_description", "supplier_types", "products", "product_categories", "keywords"
]
for col in text_columns:
    if col in df.columns:
        df[col] = df[col].fillna("").astype(str)

# %%
# Текстовые признаки: rfq_text (RFQ), supplier_text (поставщик)
df["rfq_text"] = (
    df["rfq_title"].astype(str) + " "
    + df["rfq_description"].astype(str) + " "
    + df["delivery_location"].astype(str) + " "
    + df["quantity"].astype(str) + " "
    + df["rfq_supplier_types"].astype(str)
)
df["supplier_text"] = (
    df["supplier_name"].astype(str) + " "
    + df["supplier_description"].astype(str) + " "
    + df["products"].astype(str) + " "
    + df["product_categories"].astype(str) + " "
    + df["keywords"].astype(str) + " "
    + df["distribution_area"].astype(str) + " "
    + df["supplier_country"].astype(str) + " "
    + df["supplier_types"].astype(str)
)

df.head()
# Out:
#                                  rfq_id                         rfq_title  \
# 0  08c02539-9a51-453a-9072-060baddaa0bf   Schlüssel Anhänger für Hotels
# 1  93c75bb7-1545-4279-aada-6d66b9c9e62e  elektrische Tretroller e-scooter
# 2  93c75bb7-1545-4279-aada-6d66b9c9e62e  elektrische Tretroller e-scooter
# 3  93c75bb7-1545-4279-aada-6d66b9c9e62e  elektrische Tretroller e-scooter
# 4  93c75bb7-1545-4279-aada-6d66b9c9e62e  elektrische Tretroller e-scooter
#
#                                      rfq_description       delivery_location  \
# 0  Guten Tag,\nFür unsere Kunde suchen wir Schlüs...          Pula, Kroatien
# 1  Neues Familienstartup; gesucht wird: e-scooter...  Heilbronn, Deutschland
# 2  Neues Familienstartup; gesucht wird: e-scooter...  Heilbronn, Deutschland
# 3  Neues Familienstartup; gesucht wird: e-scooter...  Heilbronn, Deutschland
# 4  Neues Familienstartup; gesucht wird: e-scooter...  Heilbronn, Deutschland
#
#                          quantity                    rfq_supplier_types  \
# 0  wird noch definiert mit Kunde   WHOLESALER, PRODUCTION, DISTRIBUTION
# 1                              10  PRODUCTION, WHOLESALER, DISTRIBUTION
# 2                              10  PRODUCTION, WHOLESALER, DISTRIBUTION
# 3                              10  PRODUCTION, WHOLESALER, DISTRIBUTION
# 4                              10  PRODUCTION, WHOLESALER, DISTRIBUTION
#
#                 supplier_name supplier_country distribution_area  \
# 0        Unique Elements GmbH               DE            europe
# 1                 Yatdim GmbH               DE     international
# 2           Erler Mobile GmbH               DE            europe
# 3                 Yatdim GmbH               DE     international
# 4  HANDELSFABRIK SACHSEN GMBH               DE
#
#                                 supplier_description  \
# 0  Wir sind Spezialisten für Schlüsselanhänger mi...
# 1  Yatdim GmbH – Ihr Partner für E‑Mobility‑Großh...
# 2  Erler Mobile produziert Elektroroller und Elek...
# 3  Yatdim GmbH – Ihr Partner für E‑Mobility‑Großh...
# 4  Kraftwerk E hat den Elektroroller Wandler K/E ...
#
#                          supplier_types  \
# 0                   Production, Service
# 1  Distribution, Production, Wholesaler
# 2  Production, Distribution, Wholesaler
# 3  Wholesaler, Production, Distribution
# 4                            Production
#
#                                             products  \
# 0  Schutzengel / Engel Schlüsselanhänger, Einkauf...
# 1  E-Bike BURCHDA RX80 fully suspended mountain b...
# 2  Industrieroller COLLY 1, Industrieroller COLLY...
# 3  "E-Bike Onesport OT16 Klappbares Elektrofahrra...
# 4  Escooter WANDLER-K/E - Electric scooter from W...
#
#          product_categories  \
# 0  Bekleidung & Accessoires
# 1                  Vehicles
# 2                 Fahrzeuge
# 3                 Fahrzeuge
# 4
#
#                                             keywords  match_type  \
# 0  Schlüsselanhänger, Schutzengel, Engel, Glücksb...       match
# 1  Burchda RX80 Elektrofahrrad, E Mountainbike 26...  weak_match
# 2  Industrieroller, Transportroller für Personen,...     related
# 3  OneSport OT16 Elektrofahrrad, E Bike klappbar ...     related
# 4               Motorroller, Escooter, Elektroroller       match
#
#                                             rfq_text  \
# 0  Schlüssel Anhänger für Hotels   Guten Tag,\nFü...
# 1  elektrische Tretroller e-scooter Neues Familie...
# 2  elektrische Tretroller e-scooter Neues Familie...
# 3  elektrische Tretroller e-scooter Neues Familie...
# 4  elektrische Tretroller e-scooter Neues Familie...
#
#                                        supplier_text
# 0  Unique Elements GmbH Wir sind Spezialisten für...
# 1  Yatdim GmbH Yatdim GmbH – Ihr Partner für E‑Mo...
# 2  Erler Mobile GmbH Erler Mobile produziert Elek...
# 3  Yatdim GmbH Yatdim GmbH – Ihr Partner für E‑Mo...
# 4  HANDELSFABRIK SACHSEN GMBH Kraftwerk E hat den...

# %% [markdown]
# ---
# ## 4. Разбиение на обучающую, валидационную и тестовую выборки (60 / 20 / 20)
#
# Используется **GroupShuffleSplit** по ключу `rfq_id`: все строки одного RFQ попадают в одну выборку. Сначала отделяем 60% групп в train и 40% во временную выборку; затем делим временную пополам — 20% validation, 20% test.

# %%
y = df["match_type"]
groups = df["rfq_id"]
feature_columns = ["rfq_text", "supplier_text"]

# 60% train, 40% временная выборка (будущие val + test)
gss1 = GroupShuffleSplit(n_splits=1, train_size=0.6, random_state=42)
train_idx, temp_idx = next(gss1.split(df, y, groups))

# Из 40% временной: половина validation, половина test (20% и 20% от всего)
gss2 = GroupShuffleSplit(n_splits=1, test_size=0.5, random_state=43)
val_idx, test_idx = next(gss2.split(df.iloc[temp_idx], y.iloc[temp_idx], groups.iloc[temp_idx]))
val_idx = np.array(temp_idx)[val_idx]
test_idx = np.array(temp_idx)[test_idx]

X_train = df.loc[train_idx, feature_columns]
y_train = y.iloc[train_idx]
X_val = df.loc[val_idx, feature_columns]
y_val = y.iloc[val_idx]
X_test = df.loc[test_idx, feature_columns]
y_test = y.iloc[test_idx]

print("Размер обучающей выборки (train):", len(X_train))
print("Размер валидационной выборки (validation):", len(X_val))
print("Размер тестовой выборки (test):", len(X_test))
# Out:
# Размер обучающей выборки (train): 646
# Размер валидационной выборки (validation): 141
# Размер тестовой выборки (test): 213

# %% [markdown]
# ---
# ## 5. Модель и обучение
#
# Конвейер: **ColumnTransformer** с двумя **TfidfVectorizer** (по `rfq_text` и `supplier_text`) и **RandomForestClassifier** с `class_weight='balanced'` для учёта дисбаланса классов.

# %%
column_transformer = ColumnTransformer(
    [
        ("rfq_tfidf", TfidfVectorizer(), "rfq_text"),
        ("supplier_tfidf", TfidfVectorizer(), "supplier_text"),
    ],
    remainder="drop",
)

pipeline = Pipeline([
    ("features", column_transformer),
    ("clf", RandomForestClassifier(n_estimators=100, random_state=42, class_weight="balanced")),
])

pipeline.fit(X_train, y_train)

# Предсказания: на validation (для подбора гиперпараметров) и на test (финальная оценка)
y_pred_val = pipeline.predict(X_val)
y_pred = pipeline.predict(X_test)

# %% [markdown]
# ---
# ## 6. Оценка качества и визуализация

# %%
print("Validation (accuracy):", round(accuracy_score(y_val, y_pred_val), 4))
print()
print("Test — classification report:")
print(classification_report(y_test, y_pred, zero_division=0))
print("Test — accuracy:", round(accuracy_score(y_test, y_pred), 4))
print("\nConfusion matrix (test):")
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# Validation (accuracy): 0.5319
#
# Test — classification report:
#               precision    recall  f1-score   support
#
#        match       0.75      0.99      0.85       159
#      related       0.00      0.00      0.00        21
#   weak_match       0.00      0.00      0.00        33
#
#     accuracy                           0.74       213
#    macro avg       0.25      0.33      0.28       213
# weighted avg       0.56      0.74      0.64       213
#
# Test — accuracy: 0.7418
#
# Confusion matrix (test):
# [[158   0   1]
#  [ 21   0   0]
#  [ 33   0   0]]

# %%
labels = sorted(y.unique())
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Матрица ошибок
sns.heatmap(
    cm, xticklabels=labels, yticklabels=labels, annot=True, fmt="d",
    cmap="Blues", ax=axes[0]
)
axes[0].set_title("Confusion matrix")
axes[0].set_ylabel("True")
axes[0].set_xlabel("Predicted")

# Метрики по классам
report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
metrics = ["precision", "recall", "f1-score"]
x = np.arange(len(labels))
width = 0.25
for i, m in enumerate(metrics):
    vals = [report[l].get(m, 0) for l in labels]
    axes[1].bar(x + i * width, vals, width, label=m)
    
axes[1].set_xticks(x + width)
axes[1].set_xticklabels(labels)
axes[1].set_ylabel("Score")
axes[1].set_title("Per-class metrics")
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Выводы
#
# Validation accuracy: 53.19% — на валидации модель угадывает класс примерно в половине случаев.
#
# Test accuracy: 74.18% — на тесте доля верных ответов выше, но это вводит в заблуждение.
#
# Модель по сути предсказывает почти только класс match: из 213 объектов теста в 212 случаях выдаётся «match». Классы related и weak_match не предсказываются (precision и recall по ним 0). Confusion matrix: все 21 related и все 33 weak_match отнесены к match; только один объект с истинной меткой match предсказан как weak_match.
#
# **Итог**: произошёл уход в majority class — Random Forest с текущими признаками и class_weight='balanced' не находит достаточный сигнал для related/weak_match и по умолчанию ставит match. Высокая accuracy достигается за счёт того, что match и так составляет ~75% теста, а не за счёт осмысленного разделения классов.
#
# По сравнению с Logistic Regression (v1) здесь хуже: у неё хотя бы были ненулевые recall по weak_match и related; у Random Forest в этом запуске два класса из трёх вообще не предсказываются.
